# %%
#import libraries

import pandas as pd
import seaborn as sns

import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12, 8) # Adjusts the configuration of the plot we will create
from datetime import date, datetime
pd.set_option('display.max.rows', 100)
pd.set_option('display.float_format', '{}'.format)

#Read the csv file

df = pd.read_csv(r'C:\Users\maheshpc\Desktop\Data_Analyst_Project\Python_Corelation_Project\Data_Set\movies.csv')

# %%
#print(df)
print(df.head())
print(df.count())
print(df.dtypes)
print(df['name'].count())
print(df.columns)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score     votes         director  \
# 0  June 13, 1980 (United States)    8.4  927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8   65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7 1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7  221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3  108000.0     Harold Ramis
#
#                     writer            star         country     budget  \
# ...

# %%
df[['name','budget']]
# Out:
#                                                 name      budget
# 0                                        The Shining  19000000.0
# 1                                    The Blue Lagoon   4500000.0
# 2     Star Wars: Episode V - The Empire Strikes Back  18000000.0
# 3                                          Airplane!   3500000.0
# 4                                         Caddyshack   6000000.0
# ...                                              ...         ...
# 7663                                    More to Life      7000.0
# 7664                                     Dream Round         NaN
# 7665                                   Saving Mbango     58750.0
# 7666                                    It's Just Us     15000.0
# 7667                                       Tee em el         NaN
#
# [7668 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %%
for col in df.columns:
    pctMissing = np.mean(df[col].isnull())
    #print(pctMissing)
    print('{} -- {}'.format(col, pctMissing))
# Out:
# name -- 0.0
# rating -- 0.010041731872717789
# genre -- 0.0
# year -- 0.0
# released -- 0.0002608242044861763
# score -- 0.0003912363067292645
# votes -- 0.0003912363067292645
# director -- 0.0
# writer -- 0.0003912363067292645
# star -- 0.00013041210224308815
# country -- 0.0003912363067292645
# budget -- 0.2831246739697444
# gross -- 0.02464788732394366
# company -- 0.002217005738132499
# runtime -- 0.0005216484089723526

# %%
#checking column data type
print(df.dtypes)
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# We need to see if we have any missing data
# Let's loop through the data and see if there is anything missing

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# name - 0.0%
# rating - 1.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 28.0%
# gross - 2.0%
# company - 0.0%
# runtime - 0.0%

# %%
#To replace null or empty values to 0
df.iloc[:,11].fillna(0, inplace = True)
df.iloc[:,11].isnull()

df.iloc[:, 12].fillna(0, inplace = True)
df.iloc[:, 12].isnull()

df[['budget', 'gross']] = df[['budget', 'gross']].astype('int64')

type(df['budget'].astype(int))
#Converting budget type from float to int
df['budget'].astype(int)
type(df['budget'].astype(int))
# Out:
# pandas.core.series.Series

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime     float64
# dtype: object

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score     votes         director  \
# 0  June 13, 1980 (United States)    8.4  927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8   65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7 1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7  221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3  108000.0     Harold Ramis
#
#                     writer            star         country     budget  \
# ...

# %%
# Looking at the top 15 compaies by gross revenue

CompanyGrossSum = df.groupby(['company'])[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values('gross', ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
# Out:
# company
# Warner Bros.                 56491421806
# Universal Pictures           52514188890
# Columbia Pictures            43008941346
# Paramount Pictures           40493607415
# Twentieth Century Fox        40257053857
# Walt Disney Pictures         36327887792
# New Line Cinema              19883797684
# Marvel Studios               15065592411
# DreamWorks Animation         11873612858
# Touchstone Pictures          11795832638
# Dreamworks Pictures          11635441081
# Metro-Goldwyn-Mayer (MGM)     9230230105
# Summit Entertainment          8373718838
# Pixar Animation Studios       7886344526
# Fox 2000 Pictures             7443502667
# Name: gross, dtype: int64

# %%
# Year wise highest gross earining company
dfgroup = df.loc[df.groupby('year').agg('gross').idxmax(),['year', 'gross', 'company']]
dfgroup.sort_values(by = ['year','gross'], ascending = False)
# Out:
#       year        gross                              company
# 7652  2020  461421559.0  Beijing Diqi Yinxiang Entertainment
# 7445  2019 2797501328.0                       Marvel Studios
# 7244  2018 2048359754.0                       Marvel Studios
# 7075  2017 1332698830.0                 Walt Disney Pictures
# 6846  2016 1153337496.0                       Marvel Studios
# 6663  2015 2069521700.0                            Lucasfilm
# 6494  2014 1104054072.0                   Paramount Pictures
# 6262  2013 1281508100.0        Walt Disney Animation Studios
# 6043  2012 1518815515.0                       Marvel Studios
# 5845  2011 1342321665.0                         Warner Bros.
# 5685  2010 1066970811.0                 Walt Disney Pictures
# 5445  2009 2847246203.0                Twentieth Century Fox
# 5243  2008 1005973645.0                         Warner Bros.
# 5060  2007  960996492.0                 Walt Disney Pictures
# ...

# %%
#Create new column from existing released column and extract only year part from it.
df['released'].str.split(',', 1).str[1].str[:5]

df['released'].str.split(',', 1).str[1].str[:5]
# Out:
# 0        1980
# 1        1980
# 2        1980
# 3        1980
# 4        1980
#         ...
# 7663     2020
# 7664     2020
# 7665     2020
# 7666     2020
# 7667     2020
# Name: released, Length: 7668, dtype: object

# %%
df.columns
# Out:
# Index(['name', 'rating', 'genre', 'year', 'released', 'score', 'votes',
#        'director', 'writer', 'star', 'country', 'budget', 'gross', 'company',
#        'runtime'],
#       dtype='object')

# %%
df['transformed_year'] = df['released'].str.split(',', 1).str[1].str[:5]
df['transformed_year']

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
df['released'].str.split(',', 1).str[1].str[:5]
# Out:
# 0        1980
# 1        1980
# 2        1980
# 3        1980
# 4        1980
#         ...
# 7663     2020
# 7664     2020
# 7665     2020
# 7666     2020
# 7667     2020
# Name: released, Length: 7668, dtype: object

# %%
df.sort_values(by = ['gross'], inplace = False, ascending = False).head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# ...

# %%
pd.set_option('display.max.rows', 100)

# %%
type(df)
type(pd)
# Out:
# module

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['company'].unique()
# Out:
# array(['Warner Bros.', 'Columbia Pictures', 'Lucasfilm', ...,
#        'Dow Jazz Films', 'Embi Productions', 'PK 65 Films'], dtype=object)

# %%
df['company'].sort_values(ascending = False)
#To delete duplicate values from company column
df['company'].drop_duplicates().sort_values(ascending = False)
#To delete all duplicates from df

#df.drop_duplicates()
# Out:
# 7129                                thefyzz
# 5664                            micro_scope
# 6412               iDeal Partners Film Fund
# 4007                               i5 Films
# 6793                             i am OTHER
#                        ...
# 3748                     1+2 Seisaku Iinkai
# 3024                        .406 Production
# 7525    "Weathering With You" Film Partners
# 4345        "DIA" Productions GmbH & Co. KG
# 408                                     NaN
# Name: company, Length: 2386, dtype: object

# %%
#checking budget vs gross correlation
#and company vs gross correlation

#Scatter plot - budget vs gross

plt.scatter(x = df['budget'], y = df['gross'])
plt.title('Budget Vs Gross Earnings')
plt.xlabel("Budget in $m")
plt.ylabel("Gross Earnings in $m")
plt.show()

# %%
#Plot budget Vs Gross Earning using sea born
sns.regplot(x = 'budget', y = 'gross', data = df)

sns.regplot(x = 'budget', y = 'gross', data = df, scatter_kws = {"color" : "red"}, line_kws = {"color" : "blue"})

# %%
#Let's start looking at correlation
df.corr() #pearson, kendall, spearman
df.corr(method = 'pearson')
df.corr(method = 'kendall')
df.corr(method = 'spearman')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.099045  0.469829  0.291152  0.314681  0.142977
# score    0.099045  1.000000  0.428138 -0.007500  0.132569  0.399857
# votes    0.469829  0.428138  1.000000  0.604627  0.752265  0.290159
# budget   0.291152 -0.007500  0.604627  1.000000  0.716816  0.246748
# gross    0.314681  0.132569  0.752265  0.716816  1.000000  0.256783
# runtime  0.142977  0.399857  0.290159  0.246748  0.256783  1.000000

# %%
df.corr(method = 'pearson')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.309212  0.261900  0.120811
# score    0.097995  1.000000  0.409182  0.055665  0.186392  0.399451
# votes    0.222945  0.409182  1.000000  0.486862  0.632834  0.309212
# budget   0.309212  0.055665  0.486862  1.000000  0.750157  0.269510
# gross    0.261900  0.186392  0.632834  0.750157  1.000000  0.245235
# runtime  0.120811  0.399451  0.309212  0.269510  0.245235  1.000000

# %%
correlation_matrix = df.corr(method = 'pearson')
sns.heatmap(correlation_matrix, annot = True)
plt.title ('Correlation matrix for numeric features')
plt.xlabel ('Movie Features')
plt.ylabel ('Movie Features')
plt.show()

# %%
#Looks at company feature
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
df_numerized = df.copy()
#converting all text column values to numeric values
for col_name in df_numerized.columns:
    if (df_numerized[col_name].dtype == object):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
df_numerized.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country    budget      gross  company  runtime  transformed_year
# 0  1047       54  19000000   46998772     2319    146.0                 0
# 1   327       55   4500000   58853106      731    104.0                 0
# 2  1745       55  18000000  538375067     1540    124.0                 0
# 3  2246       55   3500000   83453539     1812     88.0                 0
# 4   410       55   6000000   39846344     1777     98.0                 0

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
correlation_matrix = df_numerized.corr(method = 'pearson')
sns.heatmap(correlation_matrix, annot = True)
# sns.set(rc={"figure.figsize":(12, 8)}) #width=12, height=8
plt.title ('Correlation matrix for numeric features')
plt.xlabel ('Movie Features')
plt.ylabel ('Movie Features')
plt.show()

# %%
df_numerized.corr()
# Out:
#                       name    rating     genre      year  released     score  \
# name              1.000000 -0.008069  0.016355  0.011453 -0.011311  0.017097
# rating           -0.008069  1.000000  0.072423  0.008779  0.016613 -0.001314
# genre             0.016355  0.072423  1.000000 -0.081261  0.029822  0.027965
# year              0.011453  0.008779 -0.081261  1.000000 -0.000695  0.097995
# released         -0.011311  0.016613  0.029822 -0.000695  1.000000  0.042788
# score             0.017097 -0.001314  0.027965  0.097995  0.042788  1.000000
# votes             0.013088  0.033225 -0.145307  0.222945  0.016097  0.409182
# director          0.009079  0.019483 -0.015258 -0.020795 -0.001478  0.009559
# writer            0.009081 -0.005921  0.006567 -0.008656 -0.002404  0.019416
# star              0.006472  0.013405 -0.005477 -0.027242  0.015777 -0.001609
# country          -0.010737  0.081244 -0.037615 -0.070938 -0.020427 -0.133348
# ...

# %%
pd.set_option('display.max.rows', None)
corr_mat = df_numerized.corr()
corr_mat
corr_pairs = corr_mat.unstack()
corr_pairs
# Out:
# name              name                1.000000
#                   rating             -0.008069
#                   genre               0.016355
#                   year                0.011453
#                   released           -0.011311
#                   score               0.017097
#                   votes               0.013088
#                   director            0.009079
#                   writer              0.009081
#                   star                0.006472
#                   country            -0.010737
#                   budget              0.020548
#                   gross               0.006989
#                   company             0.009211
#                   runtime             0.010392
#                   transformed_year    0.009553
# rating            name               -0.008069
#                   rating              1.000000
#                   genre               0.072423
#                   year                0.008779
# ...

# %%
sorted_pairs = corr_pairs.sort_values(ascending = False)
sorted_pairs
# Out:
# transformed_year  transformed_year    1.000000
# runtime           runtime             1.000000
# rating            rating              1.000000
# genre             genre               1.000000
# year              year                1.000000
# released          released            1.000000
# score             score               1.000000
# votes             votes               1.000000
# director          director            1.000000
# writer            writer              1.000000
# star              star                1.000000
# country           country             1.000000
# budget            budget              1.000000
# gross             gross               1.000000
# company           company             1.000000
# name              name                1.000000
# year              transformed_year    0.992136
# transformed_year  year                0.992136
# gross             budget              0.750157
# budget            gross               0.750157
# ...

# %%
# Using factorize - this assigns a random numeric value for each unique categorical value

df.apply(lambda x: x.factorize()[0]).corr(method='pearson')
# Out:
#                       name    rating     genre      year  released     score  \
# name              1.000000  0.143938  0.036367  0.965761  0.959015 -0.046733
# rating            0.143938  1.000000 -0.086723  0.156713  0.146606  0.012595
# genre             0.036367 -0.086723  1.000000  0.037184  0.035940 -0.002437
# year              0.965761  0.156713  0.037184  1.000000  0.993190 -0.044981
# released          0.959015  0.146606  0.035940  0.993190  1.000000 -0.045761
# score            -0.046733  0.012595 -0.002437 -0.044981 -0.045761  1.000000
# votes             0.287776  0.099972  0.023285  0.312401  0.299905 -0.009749
# director          0.745905  0.085520  0.047288  0.770497  0.770876 -0.022687
# writer            0.805211  0.103623  0.033688  0.824770  0.819617 -0.034685
# star              0.731565  0.093116  0.038649  0.756400  0.754468 -0.009896
# country           0.142828  0.000494 -0.015795  0.140216  0.148468  0.023097
# ...

# %%
sorted_pairs = corr_pairs.sort_values(kind="quicksort")

print(sorted_pairs)
# Out:
# budget            genre              -0.334021
# genre             budget             -0.334021
#                   gross              -0.234297
# gross             genre              -0.234297
# genre             votes              -0.145307
# votes             genre              -0.145307
# score             country            -0.133348
# country           score              -0.133348
# gross             rating             -0.095450
# rating            gross              -0.095450
# genre             transformed_year   -0.082070
# transformed_year  genre              -0.082070
# rating            budget             -0.081939
# budget            rating             -0.081939
# genre             year               -0.081261
# year              genre              -0.081261
# runtime           country            -0.078412
# country           runtime            -0.078412
#                   transformed_year   -0.074166
# transformed_year  country            -0.074166
# ...

# %%
# We can now take a look at the ones that have a high correlation (> 0.5)

strong_pairs = sorted_pairs[abs(sorted_pairs) > 0.5]

print(strong_pairs)
# Out:
# votes             gross               0.632834
# gross             votes               0.632834
# budget            gross               0.750157
# gross             budget              0.750157
# transformed_year  year                0.992136
# year              transformed_year    0.992136
# name              name                1.000000
# company           company             1.000000
# gross             gross               1.000000
# budget            budget              1.000000
# country           country             1.000000
# star              star                1.000000
# writer            writer              1.000000
# director          director            1.000000
# votes             votes               1.000000
# score             score               1.000000
# released          released            1.000000
# year              year                1.000000
# genre             genre               1.000000
# rating            rating              1.000000
# ...

# %%
#Data driven decision:

#budget and votes have high correlation to the gross earnings
